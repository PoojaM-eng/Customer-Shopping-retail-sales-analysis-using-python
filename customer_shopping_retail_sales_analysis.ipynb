# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # import csv file data

# %%
df= pd.read_csv("C:/Users/prafu/Desktop/Pooja Backup/pro_anaconda/pro_anaconda/Customer Shopping Dataset- Retail Sales Data/customer_shopping_data.csv")
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# 2               Cash    9/11/2021         Metrocity
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# ...              ...          ...               ...
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]

# %%
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
df.tail()
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
df.shape
# Out:
# (99457, 10)

# %% [markdown]
# # check for null values

# %%
df.isnull().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %% [markdown]
# # check for duplicates

# %%
df.duplicated().value_counts()
# Out:
# False    99457
# dtype: int64

# %% [markdown]
# # columns in dataset

# %%
df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %% [markdown]
# # check for datatype of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %% [markdown]
# # change datatype of invoice_date

# %%
df['invoice_date']=df['invoice_date'].apply(pd.to_datetime)
# Out:
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '31/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '31/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '31/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '31/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '31/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '31/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '31/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '25/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# ...
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/01/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/07/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '20/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '17/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '31/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/02/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/01/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/06/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '27/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '19/04/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/04/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '31/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/03/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '15/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '30/11/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '23/10/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/02/2023' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '24/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/09/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '16/02/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '26/07/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '28/03/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/05/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '21/06/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '22/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '13/12/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '14/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '18/05/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(
# C:\Users\prafu\anaconda3\lib\site-packages\pandas\core\apply.py:1143: UserWarning: Parsing '29/01/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   mapped = lib.map_infer(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  datetime64[ns]
#  9   shopping_mall   99457 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 7.6+ MB

# %% [markdown]
# # count number of distinct elements

# %%
df.nunique()
# Out:
# invoice_no        99457
# customer_id       99457
# gender                2
# age                  52
# category              8
# quantity              5
# price                40
# payment_method        3
# invoice_date        797
# shopping_mall        10
# dtype: int64

# %% [markdown]
# # calculate percent of each gender

# %%
# calculate count of each gender

gender_count = df['gender'].value_counts()

#draw pie chart
fig, ax = plt.subplots()
ax.pie(gender_count, labels=gender_count.index, autopct='%1.1f%%' )
ax.set_title('Customer Gender Distribution')
plt.show()

# %% [markdown]
# # calculate the age groups

# %%
# define age group

age_groups= [0, 18, 25, 35, 45, 55, 65, 100]
labels=['0-17','18-24','25-34','35-44','45-54','55-64','65+']

#create age group based on age columns
df['Age Group'] =pd.cut(df['age'], bins=age_groups, labels=labels)

# draw a histrogram for age groups
fig, ax= plt.subplots(figsize=(8,6))
df['Age Group'].value_counts().sort_index().plot(kind='bar', color='orange',ax=ax)
ax.set_xlabel('Age Group')
ax.set_ylabel('Count')
ax.set_title('Customer Age Group Distribution')

#add labels to histrogram bars
for i in ax.containers:
    ax.bar_label(i)
plt.show()

# %% [markdown]
# # draw a bar chart to visualize the count of each category

# %%
category_count= df['category'].value_counts()
category_count.plot(kind='bar', color='yellow')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count of orders by category')

#add labels in the bar
for i, count in enumerate(category_count):
    plt.text(i, count+10, str(count), ha='center', fontsize=9)
    
plt.show()

# %%
# create a horizontal bar chart to visualize the average quantity for each category

category_mean = df.groupby ('category')['price'].mean().sort_values(ascending= False)
plt.figure(figsize=(8,4))
category_mean.plot(kind='barh', color='red')
plt.xlabel('Price')
plt.ylabel=('Category')
plt.title('Avg price by category')


# add labels on the bars
for i, mean in enumerate(category_mean):
    plt.text(mean+0.1, i, str(round(mean,2)), va='center', fontsize= 10)
plt.show()

# %%
# calculate the payment methods
pay_count=df['payment_method'].value_counts()

# define color for each payment method
colors=['skyblue','pink','lightgreen']

# draw pie chart
fig,ax=plt.subplots()
ax.pie(pay_count, labels=pay_count.index, colors=colors, autopct='%1.1f%%')
ax.set_title('Payment Method Distribution')

plt.show()

# %%
mall_count= df['shopping_mall'].value_counts()

fig, ax=plt.subplots(figsize=(10,6))
mall_count.plot(kind='bar',color='purple')
plt.xlabel('Shopping Mall')
plt.ylabel('Count')
plt.title('Count of customers by shopping mall')

# add labels to the bars
for i, count in enumerate(mall_count):
    plt.text(i, count+10, str(count), ha='center', fontsize=9)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7336\2526680919.py in <module>
#       4 mall_count.plot(kind='bar',color='purple')
#       5 plt.xlabel('Shopping Mall')
# ----> 6 plt.ylabel('Count')
#       7 plt.title('Count of customers by shopping mall')
#       8
#
# TypeError: 'str' object is not callable

# %%
# create a scatter plot to visualize the relationship between price and quantity

plt.scatter(x='price', y='quantity', data=df)
plt.xlabel('Price')
plt.ylabel('Quantity')
plt.title('Price vs Quantity')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7336\777858143.py in <module>
#       3 plt.scatter(x='price', y='quantity', data=df)
#       4 plt.xlabel('Price')
# ----> 5 plt.ylabel('Quantity')
#       6 plt.title('Price vs Quantity')
#       7 plt.show()
#
# TypeError: 'str' object is not callable
